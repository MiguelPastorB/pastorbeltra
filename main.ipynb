# %% [markdown]
# <a href="https://colab.research.google.com/github/MiguelPastorB/pastorbeltra/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Práctica 1
# - **Alumno:** Pastor Beltrá, Miguel
# - **Asignatura:** Extensiones de Machine Learning
# - **Curso:** 2025/2026
# - **Grupo:** pastorbeltra
#
# **Índice**
# 1. [Introducción](#introduccion)
# 2. [Repositorio y dependencias](#repo)
# 3. [Enlaces a notebooks](#enlaces)
#
# # 1. Introducción <a name="introduccion"></a>
#
# Este notebook principal se encarga de presentar la estructura del proyecto, instalar las dependencias necesarias y redirigir a los notebooks correspondientes.
#
# # 2. Repositorio y dependencias <a name="repo"></a>
#
# A continuación, dejo las celdas de código necesarias para clonar el repositorio en github, cuyo enlace es https://github.com/MiguelPastorB/pastorbeltra. Además de instalar las dependencias necesarias para el correcto funcionamiento de la práctica

# %%
# !rm -r pastorbeltra/
# !git clone https://github.com/MiguelPastorB/pastorbeltra.git
# %cd pastorbeltra/

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # 3. Enlaces a notebooks <a name="enlaces"></a>
#
# el trabajo está dividido en dos partes: Bandido de k-brazos y Entornos complejos. Por lo tanto, dejamos el enlace a los notebooks main de cada parte:
#
# * **Bandido de k-brazos:**[Notebook main.ipynb de Bandido de k-brazos](k_brazos/main.ipynb)
# * **Entornos complejos:**[Notebook main.ipynb de Entornos complejos](Entornos_Complejos/main.ipynb)
